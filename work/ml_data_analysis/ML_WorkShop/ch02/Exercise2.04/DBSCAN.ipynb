# %% [markdown]
# # Exercise2_03

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
data = pd.read_csv("circles.csv")
data.head()
# Out:
#           0         1
# 0  0.393992 -0.416376
# 1  0.528243 -0.828242
# 2 -0.740158  0.607730
# 3 -0.971016  0.316821
# 4  0.018693 -0.605288

# %%
data.plot(
    kind='scatter',
    x='0',
    y='1',
    color='k',
)

# %%
fig, ax = plt.subplots(1, 2, figsize=(9,6))
data.plot(
    kind='hist',
    x='0',
    color='k',
    ax=ax[0],
)
data.plot(
    kind='hist',
    x='1',
    color='k',
    ax=ax[1],
)

# %%
from sklearn.cluster import MeanShift

# set bandwith to 0.5
meanshift = MeanShift(bandwidth=.5)
y_pred = meanshift.fit_predict(data)

# %%
data.plot(
    kind='scatter',
    x='0',
    y='1',
    c=y_pred,
    s=25,
    cmap='plasma'
)

# %% [markdown]
# # Exercise2_04

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=.1)
y_pred = dbscan.fit_predict(data)

# %%
data.plot(
    kind='scatter',
    x='0',
    y='1',
    c=y_pred,
    s=25,
    cmap='plasma'
)
