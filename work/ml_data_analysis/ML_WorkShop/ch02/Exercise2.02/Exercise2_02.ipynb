# %% [markdown]
# # Exercise 2.01

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
data = pd.read_csv("circles.csv")
data.head()
# Out:
#           0         1
# 0  0.393992 -0.416376
# 1  0.528243 -0.828242
# 2 -0.740158  0.607730
# 3 -0.971016  0.316821
# 4  0.018693 -0.605288

# %%
data.plot(
    kind='scatter',
    x='0',
    y='1',
    title='Circle scatter',
    color='k',
)

# %%
data.loc[:, '0'].plot(
    kind='hist',
    color='k',
    title='Hist'
)

# %%
from sklearn.cluster import KMeans

best_k = []

for k in range(1, 21):
  kmeans = KMeans(n_clusters=k, random_state=42)
  kmeans.fit(data)
  best_k.append([k, kmeans.inertia_])

# %%
best_k
# Out:
# [[1, 947.0693750197634],
#  [2, 601.2620768520273],
#  [3, 363.7216019126116],
#  [4, 256.2982947414404],
#  [5, 201.87211887432596],
#  [6, 169.86373494600565],
#  [7, 152.4930349928768],
#  [8, 134.81753157728616],
#  [9, 118.55000098818522],
#  [10, 102.36587839992941],
#  [11, 87.4308631972628],
#  [12, 75.18722231398857],
#  [13, 63.96217848260879],
#  [14, 56.1155455426984],
#  [15, 48.442877793564804],
#  [16, 43.052518824255884],
#  [17, 38.817837876392886],
#  [18, 34.928623146418566],
#  [19, 31.891096504123666],
#  [20, 29.351048269291336]]

# %%
best_k = np.array(best_k)

plt.plot(best_k[:,0],best_k[:,1], color='k')
plt.show()

# %% [markdown]
# A number of cluster of 5 was selected

# %%
est_kmeans = KMeans(n_clusters=5, random_state=42)
est_kmeans.fit(data)
pred_kmeans = est_kmeans.predict(data)

# %%
plt.scatter(data.iloc[:,0], data.iloc[:,1], c=pred_kmeans)
plt.show()
